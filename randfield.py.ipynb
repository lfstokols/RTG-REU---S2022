# %%
import numpy as np
from random import random

SEED = 0
np.random.seed(SEED)

def F(x1, x2):
    n = 10
    F1 = 0
    F2 = 0
    
    for j in range(n):
        for k in range(n):
            coeffj = 2 * np.pi * j
            coeffk = 2 * np.pi * k
            
            weights = np.random.random(4)
    
            # Make weights fall between (-1, 1)
            norm = weights[0] ** 2 + weights[1] ** 2 + weights[2] ** 2 + weights[3] ** 2
            weights = [(w * 2 - 1) /norm for w in weights]
                
            F1 += - weights[0] * coeffk * np.cos(coeffj * x1) * np.cos(coeffk * x2) 
            F1 += weights[1] * coeffk * np.sin(coeffj * x1) * np.sin(coeffj * x2) 
            F1 += - weights[2] * coeffk * np.sin(coeffj * x1) * np.cos(coeffk * x2) 
            F1 += weights[3] * coeffk * np.cos(coeffj * x1) * np.sin(coeffk * x2)
            F2 += - weights[0] * coeffj * np.sin(coeffk * x1) * np.sin(coeffk * x2) 
            F2 += weights[1] * coeffj * np.cos(coeffj * x1) * np.cos(coeffk * x2) 
            F2 += - weights[2] * coeffj * np.sin(coeffj * x1) * np.cos(coeffk * x2) 
            F2 += weights[3] * coeffj * np.cos(coeffj * x1) * np.sin(coeffk * x2)
    
    return F1, F2

F1, F2= F(X, Y)
#xaxis = np.linspace(0, 4, 10)
#yaxis = np.linspace(-1, 1, 20)
#result = F(xaxis[:,None], yaxis[None,:])
#F1_comp = result[0]
#F2_comp = result[1]

x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)

[Y, X] = np.meshgrid(x, y, indexing = 'ij', sparse = 'true')
F(X, Y)
# Out:
# (array([[  939.44599084,  -118.5893023 ,     1.66754489,    92.46240279,
#            700.71923801,   338.07968585,   228.87640784,   413.54452448,
#            827.31912454,   939.44599084],
#         [  245.66876865,  -660.50926178,  -187.53662735,  -216.98732249,
#            314.41592538,   246.18484724,    20.51746185,    85.61237527,
#            299.26542423,   245.66876865],
#         [ -533.40475439,  -678.62680467,  -723.30930058,    66.77757165,
#          -1009.76294205,  -299.06749702,  -146.82734849,   650.63288759,
#            150.05625345,  -533.40475439],
#         [  508.64409183,   496.54598955,  -223.70841169,  -162.2791113 ,
#            215.52793864,   569.64753896,   585.77466322,   192.43532502,
#            549.00461183,   508.64409183],
#         [  177.91475921,    72.60563424,   -14.82600084,  -697.01267754,
#           -355.61225965,   496.15044292,   218.61162429,  -111.03715264,
#            -51.18137293,   177.91475921],
#         [  -34.16834829,  -859.48381801,    40.08235304,  -554.2813448 ,
#            141.0551216 ,  -679.23438298,   -35.05817004,  -315.63353784,
#           -395.12926802,   -34.16834829],
#         [  421.05618933,   252.84023103,   226.35785455,   958.53463438,
#            275.51385716,   233.23233041,  -621.3696644 ,   574.73728228,
#            633.93567139,   421.05618933],
#         [  519.77930473,    76.43245809,   256.1647783 ,   -27.83517584,
#            -46.61883371,   404.57187224,  -309.20440496,  -109.70954967,
#            249.20965006,   519.77930473],
#         [ -969.81241869,   148.5480067 ,   194.91358672,  -425.22708512,
#           -886.81676148,  -366.90628245,   140.91451731,  -187.84327681,
#           -960.13064153,  -969.81241869],
#         [  939.44599084,  -118.5893023 ,     1.66754489,    92.46240279,
#            700.71923801,   338.07968585,   228.87640784,   413.54452448,
#            827.31912454,   939.44599084]]),
#  array([[-1357.25944286,  -940.33484095,  -483.43103372,  -226.04285988,
#           -275.05736588,  -987.66114067,  -177.14597761,   273.15289739,
#             44.8455106 , -1357.25944286],
#         [  758.43744849,  1083.91234707,  -569.97065176,    47.51045397,
#           1231.45828814,   808.68336573,   309.92409448,   235.39992471,
#           -244.05187478,   758.43744849],
#         [ -403.80211203, -1074.66364518,   362.81825744,    18.54683853,
#           -955.08688253,    35.85736616,   301.95232684,   -68.10546437,
#            431.13693697,  -403.80211203],
#         [ -739.94593167,  -526.82844646,  -898.16517494,   198.27501918,
#           -417.1452728 ,    27.80927199,  -572.14572529,  -217.34765877,
#           -556.41478967,  -739.94593167],
#         [  167.52197542,   682.67820076,  -226.5792192 ,  -144.96224486,
#           1126.57863621,  -232.42269828,   836.07353384,   338.20387813,
#            314.68307578,   167.52197542],
#         [ -292.21895009,  -780.4692458 ,  -149.96423887,    42.79656703,
#           -785.59088769,   592.65187136,    87.76887922,  -537.32927477,
#             -8.62453665,  -292.21895009],
#         [-1086.51805391,  -545.66427847,   155.09393141,   -85.4760601 ,
#           -172.2962909 ,  -663.40521262,    -6.86431079,    87.53968195,
#           -387.5589208 , -1086.51805391],
#         [  853.51991517,   481.63128594,  -487.77003056,   521.12415198,
#            767.02911565,   805.8252311 ,    56.15787467,  1070.17857553,
#             99.22026835,   853.51991517],
#         [ -535.66499795,  -421.88204908,   263.0575554 ,  -292.67202192,
#           -518.61470045,   198.45021127,   157.43331947,  -819.78346788,
#             51.33435609,  -535.66499795],
#         [-1357.25944286,  -940.33484095,  -483.43103372,  -226.04285988,
#           -275.05736588,  -987.66114067,  -177.14597761,   273.15289739,
#             44.8455106 , -1357.25944286]]))

# %%
from pylab import figure, cm

import matplotlib.pyplot as plt

def plot_field(x1, x2,F1,F2):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    strm = ax.streamplot(x1, x2, F1, F2, linewidth=2, cmap='rainbow')
    fig.colorbar(strm.lines)
    plt.show()
    print(' ')

# Random seed 42
np.random.seed(42)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)

# %%
# Random seed 0
np.random.seed(0)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)

# %%
np.random.seed(100)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)

# %%
np.random.seed(200)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)
