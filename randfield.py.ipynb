# %%
import numpy as np
from random import random

SEED = 0
np.random.seed(SEED)

def F(x1, x2):
    n = 5
    F1 = 0
    F2 = 0
    
    for j in range(n):
        for k in range(n):
            coeffj = 2 * np.pi * j
            coeffk = 2 * np.pi * k
            
            weights = np.random.random(4)
    
            # Make weights fall between (-1, 1)
            weights = [w * 2 - 1 for w in weights]
                
            F1 += - weights[0] * coeffk * np.cos(coeffj * x1) * np.cos(coeffk * x2) 
            F1 += weights[1] * coeffk * np.sin(coeffj * x1) * np.sin(coeffj * x2) 
            F1 += - weights[2] * coeffk * np.sin(coeffj * x1) * np.cos(coeffk * x2) 
            F1 += weights[3] * coeffk * np.cos(coeffj * x1) * np.sin(coeffk * x2)
            F2 += - weights[0] * coeffj * np.sin(coeffk * x1) * np.sin(coeffk * x2) 
            F2 += weights[1] * coeffj * np.cos(coeffj * x1) * np.cos(coeffk * x2) 
            F2 += - weights[2] * coeffj * np.sin(coeffj * x1) * np.cos(coeffk * x2) 
            F2 += weights[3] * coeffj * np.cos(coeffj * x1) * np.sin(coeffk * x2)
    
    return F1, F2

F1, F2= F(X, Y)
#xaxis = np.linspace(0, 4, 10)
#yaxis = np.linspace(-1, 1, 20)
#result = F(xaxis[:,None], yaxis[None,:])
#F1_comp = result[0]
#F2_comp = result[1]

x = np.linspace(-1, 1, 10)
y = np.linspace(-1, 1, 10)

[Y, X] = np.meshgrid(x, y, indexing = 'ij', sparse = 'true')
F(X, Y)
# Out:
# (array([[ 4.12418771e-02,  1.10439826e+01, -8.55856142e+01,
#           7.42952841e+00, -4.95669278e+01, -1.12627173e+01,
#          -3.51670241e+01,  1.87464502e+01, -4.71485887e+00,
#           4.12418771e-02],
#         [ 5.01826513e+00, -3.56145788e+01, -3.69153310e+01,
#          -6.08319661e+00, -4.48727437e+01, -4.48800414e+01,
#           2.32462289e+01, -9.73000172e-01, -1.81127775e+00,
#           5.01826513e+00],
#         [ 2.15626307e+01, -5.83743337e+01, -7.10418689e+00,
#          -2.41962603e+01, -5.72246868e+00, -5.32539839e+01,
#           9.36680541e+00, -1.33713935e+00, -1.95145955e+01,
#           2.15626307e+01],
#         [ 9.50414871e+01, -2.02574165e+01, -2.56431340e-01,
#           2.18728702e+01, -1.02544393e+01,  1.21051438e+01,
#          -5.42856091e+01,  1.07352057e+00, -8.66925105e+01,
#           9.50414871e+01],
#         [-3.02986016e+00,  8.07127413e+00,  5.79151912e+01,
#           1.84974337e+01,  2.93905806e+01,  1.58371940e+01,
#           6.54794233e+01, -5.69629931e+01,  1.14991884e+01,
#          -3.02986016e+00],
#         [-2.93346313e+01,  2.26195311e+01,  9.86597880e+01,
#           1.39768685e+01,  5.39875067e+01,  1.22309042e+02,
#          -2.45048085e+01,  4.79626974e+01,  4.61611856e+00,
#          -2.93346313e+01],
#         [ 3.11750869e+01,  2.11050044e+01,  1.08407134e+01,
#          -8.21719672e+00,  2.63757564e+01, -3.67283270e+01,
#          -2.37833272e+01, -3.05432342e+01, -2.58032271e+00,
#           3.11750869e+01],
#         [-6.99920662e+01,  4.84802040e+01, -3.53330179e+00,
#           3.52460453e+01,  1.42719406e+01,  3.09215192e+01,
#           2.60952114e+01,  4.13947679e+01,  6.60573695e+01,
#          -6.99920662e+01],
#         [-5.04821541e+01,  2.92633272e+00, -3.40208273e+01,
#          -5.85260926e+01, -1.36092048e+01, -3.50478293e+01,
#           1.35530999e+01, -1.93610692e+01,  3.31408889e+01,
#          -5.04821541e+01],
#         [ 4.12418771e-02,  1.10439826e+01, -8.55856142e+01,
#           7.42952841e+00, -4.95669278e+01, -1.12627173e+01,
#          -3.51670241e+01,  1.87464502e+01, -4.71485887e+00,
#           4.12418771e-02]]),
#  array([[  26.72116999,    1.88825978,  -19.99040272,    5.58213673,
#           -32.66760897,   15.83531977,  -40.49395258,   59.64680623,
#           -16.52172824,   26.72116999],
#         [  41.27930544,  -47.36510754,  -72.41750995,   66.24073275,
#            63.55974615,  -98.65456836,   21.66642802,   22.00484171,
#             3.68613178,   41.27930544],
#         [  15.43033735,  -57.84473643,    1.22717993,   34.86193047,
#             0.49929771,   11.0015481 ,  -34.08978511,   16.27619536,
#            12.63803263,   15.43033735],
#         [  -2.95777104,  100.11759231,   57.31858072,  -48.60611556,
#            25.80578206,  -47.17100506,  -17.98479621,  -27.76178599,
#           -38.76048123,   -2.95777104],
#         [  39.32390779,   88.50212306,  -31.96337212,   53.44004405,
#           -69.04924449,  -12.27777612,   13.05689763,  -29.75936952,
#           -51.27321028,   39.32390779],
#         [ -20.7171423 ,  -76.66293449,   99.58763244,  -23.32445445,
#            23.75057436,   22.00754785,  -60.06985028,  -33.08844875,
#            68.51707561,  -20.7171423 ],
#         [  -6.97047383,   66.14291263,  -18.12759925,   32.36050416,
#            -2.56822283,  -71.90725936, -126.77500457,   50.5050443 ,
#            77.34009874,   -6.97047383],
#         [ -81.71111927,   33.4036846 ,  -55.20938209,  -45.50925388,
#           103.23479704,  -21.14303636,   39.25204079,   55.03814871,
#           -27.35587954,  -81.71111927],
#         [  -1.01229159,   11.84270846,  -23.89805275,  -15.89108434,
#           -65.34567425,   57.39535469,   89.60987058,  -60.71803429,
#             8.0172035 ,   -1.01229159],
#         [  26.72116999,    1.88825978,  -19.99040272,    5.58213673,
#           -32.66760897,   15.83531977,  -40.49395258,   59.64680623,
#           -16.52172824,   26.72116999]]))

# %%
from pylab import figure, cm

import matplotlib.pyplot as plt

def plot_field(x1, x2,F1,F2):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    strm = ax.streamplot(x1, x2, F1, F2, linewidth=2, cmap='rainbow')
    fig.colorbar(strm.lines)
    plt.show()
    print(' ')

# Random seed 42
np.random.seed(42)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)

# %%
# Random seed 0
np.random.seed(0)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)

# %%
np.random.seed(100)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)

# %%
np.random.seed(200)
F1, F2 = F(X, Y)
plot_field(X, Y, F1, F2)
